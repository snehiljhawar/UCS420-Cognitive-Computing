# %% [markdown]
# Assignment 9 (NLP-1)

# %% [markdown]
# Q1. Write a unique paragraph (5-6 sentences) about your favorite topic (e.g., sports,
# technology, food, books, etc.).
# 1. Convert text to lowercase and remove punctuaƟon.
# 2. Tokenize the text into words and sentences.
# 3. Remove stopwords (using NLTK's stopwords list).
# 4. Display word frequency distribuƟon (excluding stopwords)

# %%
import string
import nltk
from nltk.tokenize import PunktSentenceTokenizer, WordPunctTokenizer
from nltk.corpus import stopwords
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

sentence_tokenizer = PunktSentenceTokenizer(train_text="This is a test.")
word_tokenizer = WordPunctTokenizer()

paragraph = """My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue. Each chapter unravels secrets and twists that keep me guessing. The characters are complex, the plot is unpredictable, and the tension never fades. It’s a thrilling journey that I couldn’t put down until the end."""

lower_text = paragraph.lower()
clean_text = lower_text.translate(str.maketrans('', '', string.punctuation))

sentence_tokens = sentence_tokenizer.tokenize(paragraph)

word_tokens = word_tokenizer.tokenize(clean_text)

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in word_tokens if word not in stop_words]

fdist = FreqDist(filtered_words)

print("\nOriginal Text:\n", paragraph)
print("\nCleaned Text:\n", clean_text)
print("\nSentence Tokens:\n", sentence_tokens)
print("\nWord Tokens:\n", word_tokens)
print("\nFiltered Words (No Stopwords):\n", filtered_words)
print("\nWord Frequency:\n")
fdist.plot(10, title="Word Frequency Distribution (Excluding Stopwords)")
# Out:
# Original Text:
#  My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue. Each chapter unravels secrets and twists that keep me guessing. The characters are complex, the plot is unpredictable, and the tension never fades. It’s a thrilling journey that I couldn’t put down until the end.
#
# Cleaned Text:
#  my favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue each chapter unravels secrets and twists that keep me guessing the characters are complex the plot is unpredictable and the tension never fades it’s a thrilling journey that i couldn’t put down until the end
#
# Sentence Tokens:
#  ['My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue.', 'Each chapter unravels secrets and twists that keep me guessing.', 'The characters are complex, the plot is unpredictable, and the tension never fades.', 'It’s a thrilling journey that I couldn’t put down until the end.']
#
# Word Tokens:
#  ['my', 'favorite', 'book', 'is', 'a', 'captivating', 'mystery', 'thriller', 'that', 'blends', 'fiction', 'with', 'suspense', 'and', 'intrigue', 'each', 'chapter', 'unravels', 'secrets', 'and', 'twists', 'that', 'keep', 'me', 'guessing', 'the', 'characters', 'are', 'complex', 'the', 'plot', 'is', 'unpredictable', 'and', 'the', 'tension', 'never', 'fades', 'it', '’', 's', 'a', 'thrilling', 'journey', 'that', 'i', 'couldn', '’', 't', 'put', 'down', 'until', 'the', 'end']
#
# Filtered Words (No Stopwords):
#  ['favorite', 'book', 'captivating', 'mystery', 'thriller', 'blends', 'fiction', 'suspense', 'intrigue', 'chapter', 'unravels', 'secrets', 'twists', 'keep', 'guessing', 'characters', 'complex', 'plot', 'unpredictable', 'tension', 'never', 'fades', '’', 'thrilling', 'journey', '’', 'put', 'end']
#
# Word Frequency:
# <Axes: title={'center': 'Word Frequency Distribution (Excluding Stopwords)'}, xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# Q2: Stemming and LemmaƟzaƟon
# 1. Take the tokenized words from QuesƟon 1 (aŌer stopword removal).
# 2. Apply stemming using NLTK's PorterStemmer and LancasterStemmer.
# 3. Apply lemmaƟzaƟon using NLTK's WordNetLemmaƟzer.
# 4. Compare and display results of both techniques.

# %%
import nltk
import string
from nltk.tokenize import PunktSentenceTokenizer, WordPunctTokenizer
from nltk.stem import PorterStemmer, LancasterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords, wordnet
import matplotlib.pyplot as plt

word_tokenizer = WordPunctTokenizer()
sentence_tokenizer = PunktSentenceTokenizer(train_text="This is a test.")
paragraph = """My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue. Each chapter unravels secrets and twists that keep me guessing. The characters are complex, the plot is unpredictable, and the tension never fades. It’s a thrilling journey that I couldn’t put down until the end."""

lower_text = paragraph.lower()
clean_text = lower_text.translate(str.maketrans('', '', string.punctuation))
word_tokens = word_tokenizer.tokenize(clean_text)

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in word_tokens if word not in stop_words]

porter = PorterStemmer()
lancaster = LancasterStemmer()
lemmatizer = WordNetLemmatizer()

print("Word, PorterStemmer, LancasterStemmer, Lemmatizer")
print("-" * 70)
for word in filtered_words:
    porter_stem = porter.stem(word)
    lancaster_stem = lancaster.stem(word)
    lemma = lemmatizer.lemmatize(word)  
    print(word + ", " + porter_stem + ", " + lancaster_stem + ", " + lemma)
# Out:
# Word, PorterStemmer, LancasterStemmer, Lemmatizer
# ----------------------------------------------------------------------
# favorite, favorit, favorit, favorite
# book, book, book, book
# captivating, captiv, capt, captivating
# mystery, mysteri, mystery, mystery
# thriller, thriller, thriller, thriller
# blends, blend, blend, blend
# fiction, fiction, fict, fiction
# suspense, suspens, suspens, suspense
# intrigue, intrigu, intrigu, intrigue
# chapter, chapter, chapt, chapter
# unravels, unravel, unravel, unravels
# secrets, secret, secret, secret
# twists, twist, twist, twist
# keep, keep, keep, keep
# guessing, guess, guess, guessing
# characters, charact, charact, character
# complex, complex, complex, complex
# plot, plot, plot, plot
# unpredictable, unpredict, unpredict, unpredictable
# tension, tension, tend, tension
# never, never, nev, never
# fades, fade, fad, fade
# ’, ’, ’, ’
# thrilling, thrill, thrilling, thrilling
# journey, journey, journey, journey
# ’, ’, ’, ’
# put, put, put, put
# end, end, end, end

# %% [markdown]
# Q3. Regular Expressions and Text Spliƫng
# 1. Take their original text from QuesƟon 1.
# 2. Use regular expressions to:
# a. Extract all words with more than 5 leƩers.
# b. Extract all numbers (if any exist in their text).
# c. Extract all capitalized words.
# 3. Use text spliƫng techniques to:
# a. Split the text into words containing only alphabets (removing digits and special
# characters).
# b. Extract words starƟng with a vowel.

# %%
import string
import nltk
from nltk.tokenize import PunktSentenceTokenizer, WordPunctTokenizer
from nltk.corpus import stopwords
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

nltk.data.path.append(r"C:\Users\saraj\nltk_data")  
nltk.download('stopwords', download_dir=r"C:\Users\saraj\nltk_data")  
sentence_tokenizer = PunktSentenceTokenizer(train_text="This is a test.")
word_tokenizer = WordPunctTokenizer()

paragraph = """My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue. Each chapter unravels secrets and twists that keep me guessing. The characters are complex, the plot is unpredictable, and the tension never fades. It’s a thrilling journey that I couldn’t put down until the end."""

lower_text = paragraph.lower()
clean_text = lower_text.translate(str.maketrans('', '', string.punctuation))

sentence_tokens = sentence_tokenizer.tokenize(paragraph)

word_tokens = word_tokenizer.tokenize(clean_text)

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in word_tokens if word not in stop_words]
fdist = FreqDist(filtered_words)

print("\nOriginal Text:\n", paragraph)
print("\nCleaned Text:\n", clean_text)
print("\nSentence Tokens:\n", sentence_tokens)
print("\nWord Tokens:\n", word_tokens)
print("\nFiltered Words (No Stopwords):\n", filtered_words)
print("\nWord Frequency:\n")
fdist.plot(10, title="Word Frequency Distribution (Excluding Stopwords)")
# Out:
# Original Text:
#  My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue. Each chapter unravels secrets and twists that keep me guessing. The characters are complex, the plot is unpredictable, and the tension never fades. It’s a thrilling journey that I couldn’t put down until the end.
#
# Cleaned Text:
#  my favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue each chapter unravels secrets and twists that keep me guessing the characters are complex the plot is unpredictable and the tension never fades it’s a thrilling journey that i couldn’t put down until the end
#
# Sentence Tokens:
#  ['My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue.', 'Each chapter unravels secrets and twists that keep me guessing.', 'The characters are complex, the plot is unpredictable, and the tension never fades.', 'It’s a thrilling journey that I couldn’t put down until the end.']
#
# Word Tokens:
#  ['my', 'favorite', 'book', 'is', 'a', 'captivating', 'mystery', 'thriller', 'that', 'blends', 'fiction', 'with', 'suspense', 'and', 'intrigue', 'each', 'chapter', 'unravels', 'secrets', 'and', 'twists', 'that', 'keep', 'me', 'guessing', 'the', 'characters', 'are', 'complex', 'the', 'plot', 'is', 'unpredictable', 'and', 'the', 'tension', 'never', 'fades', 'it', '’', 's', 'a', 'thrilling', 'journey', 'that', 'i', 'couldn', '’', 't', 'put', 'down', 'until', 'the', 'end']
#
# Filtered Words (No Stopwords):
#  ['favorite', 'book', 'captivating', 'mystery', 'thriller', 'blends', 'fiction', 'suspense', 'intrigue', 'chapter', 'unravels', 'secrets', 'twists', 'keep', 'guessing', 'characters', 'complex', 'plot', 'unpredictable', 'tension', 'never', 'fades', '’', 'thrilling', 'journey', '’', 'put', 'end']
#
# Word Frequency:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\saraj\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <Axes: title={'center': 'Word Frequency Distribution (Excluding Stopwords)'}, xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# Q4. Custom TokenizaƟon & Regex-based Text Cleaning
# 1. Take original text from QuesƟon 1.
# 2. Write a custom tokenizaƟon funcƟon that:
# a. Removes punctuaƟon and special symbols, but keeps contracƟons (e.g.,
# "isn't" should not be split into "is" and "n't").
# b. Handles hyphenated words as a single token (e.g., "state-of-the-art" remains
# a single token).
# c. Tokenizes numbers separately but keeps decimal numbers intact (e.g., "3.14"
# should remain as is).
# 3. Use Regex SubsƟtuƟons (re.sub) to:
# a. Replace email addresses with '<EMAIL>' placeholder.
# b. Replace URLs with '<URL>' placeholder.
# c. Replace phone numbers (formats: 123-456-7890 or +91 9876543210) with
# '<PHONE>' placeholder.

# %%
import re
import string

import nltk
nltk.data.path.append(r"C:\Users\saraj\nltk_data")  
nltk.download('stopwords', download_dir=r"C:\Users\saraj\nltk_data")  

text = """My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue. 
Each chapter unravels secrets and twists that keep me guessing. The characters are complex, the plot is unpredictable, 
and the tension never fades. It’s a thrilling journey that I couldn’t put down until the end. 
Contact me at example@mail.com or visit https://www.example.com. Call 123-456-7890 or +91 9876543210 for more info."""

def custom_tokenizer(text):
    words = text.split()
    words = [word.strip(string.punctuation) for word in words]
    return words

def clean_text(text):
    words = text.split()
    for i in range(len(words)):
        if '@' in words[i]:  
            words[i] = '<EMAIL>'
        elif 'http' in words[i] or 'www' in words[i]:  
            words[i] = '<URL>'
        elif words[i].isdigit() and len(words[i]) == 10: 
            words[i] = '<PHONE>'
    return ' '.join(words)


cleaned_text = clean_text(text)
tokens = custom_tokenizer(cleaned_text)

print("Cleaned Text:\n", cleaned_text)
print("\nCustom Tokens:\n", tokens)
# Out:
# Cleaned Text:
#  My favorite book is a captivating mystery thriller that blends fiction with suspense and intrigue. Each chapter unravels secrets and twists that keep me guessing. The characters are complex, the plot is unpredictable, and the tension never fades. It’s a thrilling journey that I couldn’t put down until the end. Contact me at <EMAIL> or visit <URL> Call 123-456-7890 or +91 <PHONE> for more info.
#
# Custom Tokens:
#  ['My', 'favorite', 'book', 'is', 'a', 'captivating', 'mystery', 'thriller', 'that', 'blends', 'fiction', 'with', 'suspense', 'and', 'intrigue', 'Each', 'chapter', 'unravels', 'secrets', 'and', 'twists', 'that', 'keep', 'me', 'guessing', 'The', 'characters', 'are', 'complex', 'the', 'plot', 'is', 'unpredictable', 'and', 'the', 'tension', 'never', 'fades', 'It’s', 'a', 'thrilling', 'journey', 'that', 'I', 'couldn’t', 'put', 'down', 'until', 'the', 'end', 'Contact', 'me', 'at', 'EMAIL', 'or', 'visit', 'URL', 'Call', '123-456-7890', 'or', '91', 'PHONE', 'for', 'more', 'info']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\saraj\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
